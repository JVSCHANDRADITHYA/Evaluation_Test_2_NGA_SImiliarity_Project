# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#define Paths

csv_path = r"F:\NGA_Similarity_Project\data\published_images.csv"

# %%
data = pd.read_csv(csv_path)

# %%
data
# Out:
#                                         uuid  \
# 0       00007f61-4922-417b-8f27-893ea328206c
# 1       0000bd8c-39de-4453-b55d-5e28a9beed38
# 2       0001668a-dd1c-48e8-9267-b6d1697d43c8
# 3       00032658-8a7a-44e3-8bb8-df8c172f521d
# 4       0003d4e4-d7fd-4835-8d27-1e9e20672e39
# ...                                      ...
# 122476  fffd70ad-3551-4969-9aeb-363b33b428ea
# 122477  fffd8606-9b40-488a-86fd-0ebce51133a8
# 122478  fffe6d61-e686-478d-bafb-ddae9a48c4de
# 122479  ffff4903-aaf2-4a8f-9f09-60bddc65ddd7
# 122480  ffffc381-9fa3-470d-bfc2-441c643c6039
#
#                                                   iiifurl  \
# 0       https://api.nga.gov/iiif/00007f61-4922-417b-8f...
# 1       https://api.nga.gov/iiif/0000bd8c-39de-4453-b5...
# 2       https://api.nga.gov/iiif/0001668a-dd1c-48e8-92...
# 3       https://api.nga.gov/iiif/00032658-8a7a-44e3-8b...
# 4       https://api.nga.gov/iiif/0003d4e4-d7fd-4835-8d...
# ...                                                   ...
# ...

# %%
data.columns
# Out:
# Index(['uuid', 'iiifurl', 'iiifthumburl', 'viewtype', 'sequence', 'width',
#        'height', 'maxpixels', 'created', 'modified', 'depictstmsobjectid',
#        'assistivetext'],
#       dtype='object')

# %%
# import requests
# import os


# # Create a folder to save images
# os.makedirs("D:\downloaded_images", exist_ok=True)

# # Loop through iiif URLs and download images
# for idx, base_url in enumerate(data["iiifurl"].dropna()):
#     try:
#         image_url = f"{base_url}/full/full/0/default.jpg"
#         response = requests.get(image_url, stream=True)

#         if response.status_code == 200:
#             file_path = f"D:/downloaded_images/image_{idx}.jpg"
#             with open(file_path, "wb") as file:
#                 for chunk in response.iter_content(1024):
#                     file.write(chunk)
#             print(f"Downloaded: {file_path}")
#         else:
#             print(f"Failed: {image_url}")

#     except Exception as e:
#         print(f"Error downloading {base_url}: {e}")

# print("Download complete!")

# %%
len(data.depictstmsobjectid.dropna())
# Out:
# 122481

# %%
len(data.drop_duplicates())
# Out:
# 122481
